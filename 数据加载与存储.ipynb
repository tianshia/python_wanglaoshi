# %% [markdown]
# <a href="https://colab.research.google.com/github/tianshia/python_wanglaoshi/blob/main/%E6%95%B0%E6%8D%AE%E5%8A%A0%E8%BD%BD%E4%B8%8E%E5%AD%98%E5%82%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # pandas 进阶修炼
# <br>
#
# 本习题基于 `pandas` 版本 `1.1.3`，所有内容应当在 `Jupyter Notebook` 中执行以获得最佳效果。
#
# 不同版本之间写法可能会有少许不同，如若碰到此情况，你应该学会如何自行检索解决。

# %% [markdown]
# # 1 - 数据加载与存储

# %% [markdown]
# 是的，常常被忽略的「<font color=#E36C07>**数据加载与存储**</font>」也大有门道且值得作为本套习题的开门之章。
#
# 在一次数据分析的过程中，你可能只会读取或存储一两次数据集。
#
# **但若能灵活掌握各项设置，在读取阶段就将数据筛选、匹配、格式指定等操作完成，有时会为我们节省大量时间。**
#
# 在本节习题中，我将 pandas 数据分析中常见的数据读取与存储操作进行整理。
#
# <font color=#E36C07>**既可以用于巩固、学习各种操作，也可以作为速查手册使用**</font>。

# %% [markdown]
# ## 初始化
#
# <br>
#
# 该 `Notebook` 版本为**习题+答案版**
#
#
# <font color=#E36C07>**请执行下方单元格以初始化读取本节习题的答案**</font>
#
# 执行完毕后，你可以使用  <font color=#E36C07> **ans(1)** </font>  来查看第 1 题的参考解答，其余习题类似。
#
# 注意：所有答案并非固定（唯一），我提供的答案仅供参考（并非推荐答案或者最优解）！

# %%
import sys
import pandas as pd
sys.path.append('../document/')
from inits import initialize,ans

res = initialize("../document/answer-1.txt")
# Out:
# ***************正在初始化***************
# *************读取到配置文件*************
# ***************初始化成功***************

# %% [markdown]
# ## 1-1 数据读取

# %% [markdown]
# ### 1 读取 Excel 文件
#
# <br>
#
# - 读取当前目录下 `某招聘网站数据.csv` 文件
#
# - 读取当前目录下 `TOP250.xlsx` 文件
#
# **注意**：使用 `pandas` 读取 `CSV` 与 读取 `xlsx` 格式的 `Excel` 文件方法大致相同
#
# 因此接下来与 `Excel` 相关的操作均以 `CSV` 格式进行出题。

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
print('pd'+str(pd.__version__))
print('np'+str(np.__version__))
print('plt'+str(matplotlib.__version__))
# Out:
# pd1.3.5
# np1.21.6
# plt3.2.2

# %%
data = pd.read_csv("某招聘网站数据.csv")
data = pd.read_excel("TOP250.xlsx")

# %%
data
# Out:
#            片名  上映年份   评分     评价人数        导演  \
# 0      肖申克的救赎  1994  9.7  2317937  弗兰克·德拉邦特
# 1        霸王别姬  1993  9.6  1720638       陈凯歌
# 2        阿甘正传  1994  9.5  1743966  罗伯特·泽米吉斯
# 3     这个杀手不太冷  1994  9.4  1922740     吕克·贝松
# 4       泰坦尼克号  1997  9.4  1706127   詹姆斯·卡梅隆
# ..        ...   ...  ...      ...       ...
# 245        浪潮  2008  8.7   223511   丹尼斯·甘塞尔
# 246  小萝莉的猴神大叔  2015  8.4   404886     卡比尔·汗
# 247        追随  1998  8.9   149521  克里斯托弗·诺兰
# 248      网络谜踪  2018  8.6   430811   阿尼什·查甘蒂
# 249      黑鹰坠落  2001  8.7   239402   雷德利·斯科特
#
#                                                编剧  \
# 0                                弗兰克·德拉邦特 / 斯蒂芬·金
# 1                                        芦苇 / 李碧华
# 2                                艾瑞克·罗斯 / 温斯顿·格鲁姆
# 3                                           吕克·贝松
# 4                                         詹姆斯·卡梅隆
# ..                                            ...
# 245  丹尼斯·甘塞尔 / 彼得·图万斯 / 约翰尼·道金斯 / 罗恩·比恩巴赫 / 罗恩·琼斯
# 246                            卡比尔·汗 / 维杰耶德拉·普拉萨德
# 247                                      克里斯托弗·诺兰
# 248                             阿尼什·查甘蒂 / 赛弗·奥哈尼安
# 249                                  肯·诺兰 / 马克·鲍登
#
#                                                     主演                 类型  \
# 0    蒂姆·罗宾斯 / 摩根·弗里曼 / 鲍勃·冈顿 / 威廉姆·赛德勒 / 克兰西·布朗 / 吉...            剧情 / 犯罪
# 1    张国荣 / 张丰毅 / 巩俐 / 葛优 / 英达 / 蒋雯丽 / 吴大维 / 吕齐 / 雷汉...       剧情 / 爱情 / 同性
# 2    汤姆·汉克斯 / 罗宾·怀特 / 加里·西尼斯 / 麦凯尔泰·威廉逊 / 莎莉·菲尔德 / ...            剧情 / 爱情
# 3    让·雷诺 / 娜塔莉·波特曼 / 加里·奥德曼 / 丹尼·爱罗 / 彼得·阿佩尔 / 迈克尔...       剧情 / 动作 / 犯罪
# 4    莱昂纳多·迪卡普里奥 / 凯特·温丝莱特 / 比利·赞恩 / 凯西·贝茨 / 弗兰西丝·费舍...       剧情 / 爱情 / 灾难
# ..                                                 ...                ...
# 245  于尔根·福格尔 / 弗雷德里克·劳 / 马克思·雷迈特 / 詹妮弗·乌尔里希 / 克里斯蒂安...            剧情 / 惊悚
# 246  萨尔曼·汗 / 哈莎莉·马洛特拉 / 卡琳娜·卡普尔 / 纳瓦祖丁·席迪圭 / 欧姆·普瑞 ...       剧情 / 喜剧 / 动作
# 247  杰里米·西奥伯德 / 亚历克斯·霍 / 露西·拉塞尔 / 约翰·诺兰 / 迪克·布拉德塞尔 ...       悬疑 / 惊悚 / 犯罪
# 248  约翰·赵 / 米切尔·拉 / 黛博拉·梅辛 / 约瑟夫·李 / 萨拉·米博·孙 / 亚历克丝...  剧情 / 悬疑 / 惊悚 / 犯罪
# 249  乔什·哈奈特 / 伊万·麦克格雷格 / 汤姆·塞兹摩尔 / 金·寇兹 / 艾文·布莱纳 / ...       动作 / 历史 / 战争
#
#     国家/地区     语言  时长(分钟)
# 0      美国     英语     142
# 1      中国  汉语普通话     171
# 2      美国     英语     142
# 3      法国    英语      110
# 4      美国    英语      194
# ..    ...    ...     ...
# 245    德国     德语     107
# 246    印度   印地语      159
# 247    英国     英语      69
# 248    美国     英语     102
# 249    美国    英语      144
#
# [250 rows x 11 columns]

# %% [markdown]
# ### 2 读取 Excel 文件｜指定位置
#
# 在大多数情况下，我们会将 `notebook` 和数据源文件放在同一个目录（文件夹下），这样直接使用`pd.read_xxx("文件名")`即可成功读取。
#
# 但有时需要读取的文件和 `notebook` 不在同一个目录下，这时可以使用绝对路径或者相对本 `notebook` 的路径。
#
# 现在请读取本套习题中第二章节下的数据，即 `2 - 个性化显示设置/data.csv`

# %%
data=pd.read_csv("../2-个性化设置/data.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-40bfabe81f62> in <module>
# ----> 1 data=pd.read_csv("../2-个性化设置/data.csv")
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '../2-个性化设置/data.csv'

# %% [markdown]
# # 新段落

# %% [markdown]
# # 新段落

# %% [markdown]
# ###  3 读取 Excel 文件｜指定行（顺序）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 <font color = '#5F5FFC'>前20行</font>

# %%
data=pd.read_csv("某招聘网站数据.csv",nrows=20)
data
# Out:
#     positionId      positionName  companyId companySize industryField  \
# 0      6802721              数据分析     475770     50-150人      移动互联网,电商
# 1      5204912              数据建模      50735    150-500人            电商
# 2      6877668              数据分析     100125     2000人以上    移动互联网,企业服务
# 3      6496141              数据分析      26564   500-2000人            电商
# 4      6467417              数据分析      29211     2000人以上         物流丨运输
# 5      6882347              数据分析      94826     50-150人      移动互联网,社交
# 6      6841659              数据分析     348784     50-150人      移动互联网,电商
# 7      6764018           数据建模工程师      13163   500-2000人         移动互联网
# 8      6458372            数据分析专家      34132    150-500人     数据服务,广告营销
# 9      6786904             数据分析师      13163   500-2000人         移动互联网
# 10     6804629             数据分析师      34132    150-500人     数据服务,广告营销
# 11     6847013  大数据分析工程师(J11108)      55046     2000人以上    移动互联网,企业服务
# 12     6763962           数据分析工程师      13163   500-2000人         移动互联网
# 13     6804489           资深数据分析师      34132    150-500人     数据服务,广告营销
# 14     6657285             数据分析师       7461     2000人以上          企业服务
# 15     6882983       产品运营（偏数据分析）       7461     2000人以上          企业服务
# 16     6486988       资深数据分析师（杭州）       7461     2000人以上          企业服务
# 17     5519962           大数据建模总监      50735    150-500人            电商
# 18     5559894   数据建模专家-杭州-01546       6502   500-2000人     信息安全,数据服务
# 19     6702852      数据分析专家（游戏业务）        593     2000人以上      移动互联网,游戏
#
#    financeStage                     companyLabelList  firstType secondType  \
# 0            A轮     ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1            B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2          上市公司     ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3         D轮及以上    ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4          上市公司     ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# 5            B轮     ['股票期权', '扁平管理', '五险一金', '岗位晋升']  产品|需求|项目类       数据分析
# 6            A轮     ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析
# 7          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 8            A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 9          上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 10           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 11         上市公司     ['技能培训', '年底双薪', '带薪年假', '岗位晋升']  开发|测试|运维类       数据开发
# 12         上市公司     ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 13           A轮  ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 14         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  产品|需求|项目类       数据分析
# 15         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  运营|编辑|客服类         运营
# 16         上市公司   ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  开发|测试|运维类       数据开发
# 17           B轮     ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 18        D轮及以上     ['技能培训', '股票期权', '绩效奖金', '岗位晋升']  开发|测试|运维类       数据开发
# 19        不需要融资     ['五险一金', '交通补助', '绩效奖金', '节日礼物']  开发|测试|运维类       数据开发
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0       数据分析  ...  NaN      0       0       0              NaN
# 1         建模  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4       数据分析  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7         建模  ...  NaN      0       0       0              NaN
# 8     其他数据分析  ...  NaN      0       0       0              NaN
# 9      BI工程师  ...  NaN      0       0       0              NaN
# 10      数据分析  ...  NaN      0       0       0              NaN
# 11      数据分析  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15      数据运营  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17        建模  ...  NaN      0       0       0              NaN
# 18        建模  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []         False
# 3                    NaN         0      0                   []          True
# 4                    NaN         0      0                   []          True
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []         False
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []         False
# 9                    NaN         0      0                   []          True
# 10                   NaN         0      0                   []         False
# 11                   NaN         0      0                   []         False
# 12                   NaN         0      0                   []          True
# 13                   NaN         0      0                   []         False
# 14                   NaN         0      0                   []          True
# 15                   NaN         0      0                   []          True
# 16                   NaN         0      0                   []          True
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []          True
#
# [20 rows x 52 columns]

# %% [markdown]
# ###  4 读取 Excel 文件｜指定行（跳过）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件并<font color = '#5F5FFC'>跳过前20行</font>

# %%
data=pd.read_csv("某招聘网站数据.csv",skiprows=[i for i in range(1,21)])

# %%
data
# Out:
#     positionId           positionName  companyId companySize industryField  \
# 0      6829277                资深数据分析师        593     2000人以上      移动互联网,游戏
# 1      6267370                 数据分析专家      31544    150-500人          数据服务
# 2      5927901                 数据分析经理         62     2000人以上         文娱丨内容
# 3      6862245                 数据分析专家     473950     50-150人         移动互联网
# 4      5604926                  数据分析师     143884     50-150人      移动互联网,金融
# ..         ...                    ...        ...         ...           ...
# 80     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 81     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 82     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 83     6704835                BI数据分析师      52840     2000人以上            电商
# 84     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#    financeStage                      companyLabelList  firstType secondType  \
# 0         不需要融资      ['五险一金', '交通补助', '绩效奖金', '节日礼物']  产品|需求|项目类     高端产品职位
# 1         不需要融资    ['专业红娘牵线', '节日礼物', '技能培训', '岗位晋升']  开发|测试|运维类       数据开发
# 2            C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       产品经理
# 3           未融资                                    []  产品|需求|项目类       数据分析
# 4            A轮      ['股票期权', '带薪年假', '绩效奖金', '年底双薪']  开发|测试|运维类       数据开发
# ..          ...                                   ...        ...        ...
# 80           C轮      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 81           C轮      ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 82        不需要融资                                    []  开发|测试|运维类       数据开发
# 83         上市公司      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 84        不需要融资      ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0     数据分析专家  ...  NaN      0       0       0              NaN
# 1       数据分析  ...  NaN      0       0       0              NaN
# 2     其他产品经理  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4       数据分析  ...  NaN      0       0       0              NaN
# ..       ...  ...  ...    ...     ...     ...              ...
# 80      数据分析  ...  NaN      0       0       0              NaN
# 81    商业数据分析  ...  NaN      0       0       0              NaN
# 82      数据分析  ...  NaN      0       0       0              NaN
# 83      数据分析  ...  NaN      0       0       0              NaN
# 84    其他数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []          True
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []          True
# 3                    NaN         0      0                   []         False
# 4                    NaN         0      0                   []         False
# ..                   ...       ...    ...                  ...           ...
# 80                   NaN         0      0                   []         False
# 81                   NaN         0      0                   []         False
# 82                   NaN         0      0                   []         False
# 83                   NaN         0      0                   []          True
# 84                   NaN         0      0                   []          True
#
# [85 rows x 52 columns]

# %% [markdown]
# ###  5 读取 Excel 文件｜指定行（条件）
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件中全部<font color = '#5F5FFC'>偶数行</font>
#
# 思考：如果是读取全部奇数行，或者更多满足指定条件的行呢？

# %%
data=pd.read_csv("某招聘网站数据.csv",skiprows=lambda x:(x!=0)and not x%2)

# %%
data
# Out:
#     positionId             positionName  companyId companySize industryField  \
# 0      6802721                     数据分析     475770     50-150人      移动互联网,电商
# 1      6877668                     数据分析     100125     2000人以上    移动互联网,企业服务
# 2      6467417                     数据分析      29211     2000人以上         物流丨运输
# 3      6841659                     数据分析     348784     50-150人      移动互联网,电商
# 4      6458372                   数据分析专家      34132    150-500人     数据服务,广告营销
# 5      6804629                    数据分析师      34132    150-500人     数据服务,广告营销
# 6      6763962                  数据分析工程师      13163   500-2000人         移动互联网
# 7      6657285                    数据分析师       7461     2000人以上          企业服务
# 8      6486988              资深数据分析师（杭州）       7461     2000人以上          企业服务
# 9      5559894          数据建模专家-杭州-01546       6502   500-2000人     信息安全,数据服务
# 10     6829277                  资深数据分析师        593     2000人以上      移动互联网,游戏
# 11     5927901                   数据分析经理         62     2000人以上         文娱丨内容
# 12     5604926                    数据分析师     143884     50-150人      移动互联网,金融
# 13     6850849                   数据分析专家     255742    150-500人         金融,电商
# 14     6657704                    数据分析师     165220    150-500人            社交
# 15     6234992                    数据分析师        542   500-2000人          消费生活
# 16     6804489                  资深数据分析师      34132    150-500人     数据服务,广告营销
# 17     6228290                  商业数据分析师     509360     50-150人    移动互联网,企业服务
# 18     6886661                  浙江数据分析师     321001    150-500人       金融,数据服务
# 19     6601086                    数据分析师      21187    150-500人    企业服务,移动互联网
# 20     6791055                  高级数据分析师     432882    150-500人         移动互联网
# 21     6344146                  资深数据分析师     522865    150-500人            游戏
# 22     6653757                  银行数据分析岗      23403     2000人以上          企业服务
# 23     6228290                  商业数据分析师     509360     50-150人    移动互联网,企业服务
# 24     6067812                   数据分析专员      98316     2000人以上       电商,消费生活
# 25     6680900         数据分析师 (MJ000250)     114335    150-500人          数据服务
# 26     6486069             解决方案顾问/数据分析师     166666    150-500人     企业服务,数据服务
# 27     6046775                   数据分析专家     133429     50-150人    移动互联网,消费生活
# 28     6037742       资深数据分析师 (MJ000088)     127233    150-500人          电子商务
# 29     5921220                  财务数据分析师     137388    150-500人      移动互联网,电商
# 30     5978750        数据分析师（保险）13-01-19      18655     2000人以上         汽车丨出行
# 31     6191993          数据分析专家03-10-217      18655     2000人以上         汽车丨出行
# 32     6789831                  数据分析实习生     306282    150-500人    移动互联网,数据服务
# 33     6848382      资深数据分析师（商品方向）G01053     179243   500-2000人      电商,移动互联网
# 34     6829736         数据分析负责人 or 数据分析师     205347     2000人以上         金融,电商
# 35     6728610                 高级数据分析专员      98316     2000人以上       电商,消费生活
# 36     6794326                  BI数据分析师     374014   500-2000人      移动互联网,金融
# 37     6837340             数据分析-2020届春招     205347     2000人以上         金融,电商
# 38     6896403             智能数据分析引擎研发专家     285786     2000人以上            电商
# 39     5683671       数据分析实习生 (MJ000087)     114335    150-500人          数据服务
# 40     6310387                 业务与数据分析师      93448    150-500人     人工智能,数据服务
# 41     6820395  产品经理/数据分析（核心业务）-2020届春招     205347     2000人以上         金融,电商
# 42     6747553                  资深数据分析师     581460     2000人以上      电商,汽车丨出行
# 43     6496980               数据分析师-Lark         62     2000人以上         文娱丨内容
# 44     6597345                  资深数据分析师      57350   500-2000人         移动互联网
# 45     6456921                   数据分析专家     738016     50-150人       电商,数据服务
# 46     6813626                 资深数据分析专员     165939    150-500人          数据服务
# 47     6818950                  资深数据分析师     165939    150-500人          数据服务
# 48     6767669                   数据分析专员      92417     2000人以上    移动互联网,广告营销
# 49     6655562                数据分析建模工程师  117422215     50-150人     数据服务,信息安全
# 50     6884346                    数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 51     6803432          奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 52     6728058    数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#    financeStage                      companyLabelList  firstType secondType  \
# 0            A轮      ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1          上市公司      ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 2          上市公司      ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# 3            A轮      ['大牛团队', '扁平管理', '年底双薪', '股票期权']  产品|需求|项目类       数据分析
# 4            A轮   ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 5            A轮   ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  产品|需求|项目类       数据分析
# 6          上市公司      ['绩效奖金', '股票期权', '年底双薪', '专项奖金']  开发|测试|运维类       数据开发
# 7          上市公司    ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  产品|需求|项目类       数据分析
# 8          上市公司    ['工程师氛围', '弹性工作', '扁平管理', '上班不打卡']  开发|测试|运维类       数据开发
# 9         D轮及以上      ['技能培训', '股票期权', '绩效奖金', '岗位晋升']  开发|测试|运维类       数据开发
# 10        不需要融资      ['五险一金', '交通补助', '绩效奖金', '节日礼物']  产品|需求|项目类     高端产品职位
# 11           C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       产品经理
# 12           A轮      ['股票期权', '带薪年假', '绩效奖金', '年底双薪']  开发|测试|运维类       数据开发
# 13           C轮   ['持牌金融机构', '跨境支付', '跨境金融', '国际化团队']  开发|测试|运维类       数据开发
# 14        不需要融资      ['绩效奖金', '带薪年假', '交通补助', '午餐补助']  产品|需求|项目类       数据分析
# 15        D轮及以上      ['六险一金', '快乐高效文化', '绩效奖金', '信任']  产品|需求|项目类       数据分析
# 16           A轮   ['开放式办公', '扁平管理', '带薪假期', '弹性工作时间']  开发|测试|运维类       数据开发
# 17           B轮         ['定期体检', '帅哥多', '领导好', '美女多']     市场|商务类      市场|营销
# 18        D轮及以上      ['年底双薪', '午餐补助', '年终分红', '绩效奖金']  开发|测试|运维类       数据开发
# 19          天使轮       ['带薪年假', '年轻团队', '股票期权', '下午茶']  产品|需求|项目类       数据分析
# 20        不需要融资    ['技术大牛', '领导nice', '帅哥美女', '环境超棒']  产品|需求|项目类       数据分析
# 21        不需要融资      ['年底双薪', '专项奖金', '提供三餐', '便捷班车']  开发|测试|运维类       数据开发
# 22         上市公司      ['五险一金', '通讯津贴', '带薪年假', '定期体检']  开发|测试|运维类       数据开发
# 23           B轮         ['定期体检', '帅哥多', '领导好', '美女多']     市场|商务类      市场|营销
# 24         上市公司      ['午餐补助', '带薪年假', '定期体检', '年度旅游']  产品|需求|项目类       数据分析
# 25           B轮       ['股票期权', '弹性工作', '领导好', '五险一金']  产品|需求|项目类       产品经理
# 26           B轮      ['股票期权', '绩效奖金', '带薪年假', '弹性工作']  产品|需求|项目类       数据分析
# 27          未融资       ['年底双薪', '专项奖金', '美女多', '弹性工作']  产品|需求|项目类     高端产品职位
# 28        不需要融资      ['带薪年假', '绩效奖金', '定期体检', '弹性工作']  开发|测试|运维类       数据开发
# 29        不需要融资      ['年终分红', '绩效奖金', '定期体检', '年底双薪']  综合职能|高级管理         财务
# 30        D轮及以上        ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 31        D轮及以上        ['技能培训', 'Geek', '开放', '扁平管理']  开发|测试|运维类       数据开发
# 32          未融资      ['弹性工作', '技能培训', '岗位晋升', '五险一金']  开发|测试|运维类       数据开发
# 33         上市公司      ['绩效奖金', '股票期权', '五险一金', '午餐补助']  产品|需求|项目类       数据分析
# 34         上市公司       ['带薪年假', '定期体检', '免费班车', '领导好']  开发|测试|运维类       数据开发
# 35         上市公司      ['午餐补助', '带薪年假', '定期体检', '年度旅游']     市场|商务类      市场|营销
# 36           B轮       ['弹性工作', '扁平管理', '领导好', '五险一金']  产品|需求|项目类       数据分析
# 37         上市公司       ['带薪年假', '定期体检', '免费班车', '领导好']  产品|需求|项目类       数据分析
# 38         上市公司      ['年底双薪', '带薪年假', '午餐补助', '弹性工作']  开发|测试|运维类       后端开发
# 39           B轮       ['股票期权', '弹性工作', '领导好', '五险一金']  开发|测试|运维类       后端开发
# 40           B轮      ['技能培训', '股票期权', '带薪年假', '绩效奖金']  产品|需求|项目类       数据分析
# 41         上市公司       ['带薪年假', '定期体检', '免费班车', '领导好']  产品|需求|项目类       产品经理
# 42        D轮及以上       ['阿里合资', '六险一金', '独角兽', '行业先驱']     市场|商务类      市场|营销
# 43           C轮  ['扁平管理', '弹性工作', '大厨定制三餐', '就近租房补贴']  产品|需求|项目类       数据分析
# 44           A轮      ['岗位晋升', '年度旅游', '年底双薪', '午餐补助']  产品|需求|项目类       数据分析
# 45          未融资                                    []  开发|测试|运维类       数据开发
# 46        不需要融资      ['年底双薪', '带薪年假', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 47        不需要融资      ['年底双薪', '带薪年假', '午餐补助', '定期体检']  开发|测试|运维类       数据开发
# 48         上市公司      ['节日礼物', '股票期权', '带薪年假', '岗位晋升']  产品|需求|项目类       数据分析
# 49           A轮   ['午餐补助', '带薪年假', '16到18薪', '法定节假日']  开发|测试|运维类       人工智能
# 50           C轮      ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 51        不需要融资                                    []  开发|测试|运维类       数据开发
# 52        不需要融资      ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#    thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0       数据分析  ...  NaN      0       0       0              NaN
# 1       数据分析  ...  NaN      0       0       0              NaN
# 2       数据分析  ...  NaN      0       0       0              NaN
# 3       数据分析  ...  NaN      0       0       0              NaN
# 4     其他数据分析  ...  NaN      0       0       0              NaN
# 5       数据分析  ...  NaN      0       0       0              NaN
# 6       数据分析  ...  NaN      0       0       0              NaN
# 7       数据分析  ...  NaN      0       0       0              NaN
# 8       数据分析  ...  NaN      0       0       0              NaN
# 9         建模  ...  NaN      0       0       0              NaN
# 10    数据分析专家  ...  NaN      0       0       0              NaN
# 11    其他产品经理  ...  NaN      0       0       0              NaN
# 12      数据分析  ...  NaN      0       0       0              NaN
# 13      数据分析  ...  NaN      0       0       0              NaN
# 14      数据分析  ...  NaN      0       0       0              NaN
# 15      数据分析  ...  NaN      0       0       0              NaN
# 16      数据分析  ...  NaN      0       0       0              NaN
# 17    商业数据分析  ...  NaN      0       0       0              NaN
# 18      数据分析  ...  NaN      0       0       0              NaN
# 19      数据分析  ...  NaN      0       0       0              NaN
# 20      数据分析  ...  NaN      0       0       0              NaN
# 21      数据分析  ...  NaN      0       0       0              NaN
# 22      数据分析  ...  NaN      0       0       0              NaN
# 23    商业数据分析  ...  NaN      0       0       0              NaN
# 24      数据分析  ...  NaN      0       0       0              NaN
# 25     数据分析师  ...  NaN      0       0       0              NaN
# 26      数据分析  ...  NaN      0       0       0              NaN
# 27    数据分析专家  ...  NaN      0       0       0              NaN
# 28      数据分析  ...  NaN      0       0       0              NaN
# 29      财务风控  ...  NaN      0       0       0              NaN
# 30      数据分析  ...  NaN      0       0       0              NaN
# 31      数据分析  ...  NaN      0       0       0              NaN
# 32      数据分析  ...  NaN      0       0       0              NaN
# 33      数据分析  ...  NaN      0       0       0              NaN
# 34      数据分析  ...  NaN      0       0       0              NaN
# 35    商业数据分析  ...  NaN      0       0       0              NaN
# 36        BI  ...  NaN      0       0       0              NaN
# 37      数据分析  ...  NaN      0       0       0              NaN
# 38      Java  ...  NaN      0       0       0              NaN
# 39      数据采集  ...  NaN      0       0       0              NaN
# 40      数据分析  ...  NaN      0       0       0              NaN
# 41      产品经理  ...  NaN      0       0       0              NaN
# 42    商业数据分析  ...  NaN      0       0       0              NaN
# 43    其他数据分析  ...  NaN      0       0       0              NaN
# 44      数据分析  ...  NaN      0       0       0              NaN
# 45      数据分析  ...  NaN      0       0       0              NaN
# 46      数据分析  ...  NaN      0       0       0              NaN
# 47      数据分析  ...  NaN      0       0       0              NaN
# 48      数据分析  ...  NaN      0       0       0              NaN
# 49      机器学习  ...  NaN      0       0       0              NaN
# 50      数据分析  ...  NaN      0       0       0              NaN
# 51      数据分析  ...  NaN      0       0       0              NaN
# 52    其他数据分析  ...  NaN      0       0       0              NaN
#
#    promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                    NaN         0      0                   []         False
# 1                    NaN         0      0                   []         False
# 2                    NaN         0      0                   []          True
# 3                    NaN         0      0                   []         False
# 4                    NaN         0      0                   []         False
# 5                    NaN         0      0                   []         False
# 6                    NaN         0      0                   []          True
# 7                    NaN         0      0                   []          True
# 8                    NaN         0      0                   []          True
# 9                    NaN         0      0                   []         False
# 10                   NaN         0      0                   []          True
# 11                   NaN         0      0                   []          True
# 12                   NaN         0      0                   []         False
# 13                   NaN         0      0                   []         False
# 14                   NaN         0      0                   []         False
# 15                   NaN         0      0                   []          True
# 16                   NaN         0      0                   []         False
# 17                   NaN         0      0                   []         False
# 18                   NaN         0      0                   []         False
# 19                   NaN         0      0                   []         False
# 20                   NaN         0      0                   []         False
# 21                   NaN         0      0                   []         False
# 22                   NaN         0      0                   []         False
# 23                   NaN         0      0                   []         False
# 24                   NaN         0      0                   []         False
# 25                   NaN         0      0                   []         False
# 26                   NaN         0      0                   []         False
# 27                   NaN         0      0                   []         False
# 28                   NaN         0      0                   []         False
# 29                   NaN         0      0                   []         False
# 30                   NaN         0      0                   []          True
# 31                   NaN         0      0                   []          True
# 32                   NaN         0      0                   []         False
# 33                   NaN         0      0                   []          True
# 34                   NaN         0      0                   []          True
# 35                   NaN         0      0                   []         False
# 36                   NaN         0      0                   []         False
# 37                   NaN         0      0                   []          True
# 38                   NaN         0      0                   []          True
# 39                   NaN         0      0                   []         False
# 40                   NaN         0      0                   []         False
# 41                   NaN         0      0                   []          True
# 42                   NaN         0      0                   []         False
# 43                   NaN         0      0                   []          True
# 44                   NaN         0      0                   []         False
# 45                   NaN         0      0                   []         False
# 46                   NaN         0      0                   []         False
# 47                   NaN         0      0                   []         False
# 48                   NaN         0      0                   []         False
# 49                   NaN         0      0                   []         False
# 50                   NaN         0      0                   []         False
# 51                   NaN         0      0                   []         False
# 52                   NaN         0      0                   []          True
#
# [53 rows x 52 columns]

# %% [markdown]
# ### 6 读取 Excel 文件｜指定列（列号）
#
# <br>
#
# **根据指定列号读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的第 `1、3、5` 列

# %%
data=pd.read_csv("某招聘网站数据.csv",usecols=[0,2,4])

# %%
data
# Out:
#      positionId  companyId industryField
# 0       6802721     475770      移动互联网,电商
# 1       5204912      50735            电商
# 2       6877668     100125    移动互联网,企业服务
# 3       6496141      26564            电商
# 4       6467417      29211         物流丨运输
# ..          ...        ...           ...
# 100     6884346      21236   移动互联网,医疗丨健康
# 101     6849100      72076      移动互联网,电商
# 102     6803432     751158         移动互联网
# 103     6704835      52840            电商
# 104     6728058       2474         汽车丨出行
#
# [105 rows x 3 columns]

# %% [markdown]
# ###  7 读取 Excel 文件｜指定列（列名）
#
# <br>
#
# **根据指定列名读取**
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列

# %%
data=pd.read_csv("某招聘网站数据.csv",usecols=['positionId','positionName','salary'])
data
# Out:
#      positionId           positionName  salary
# 0       6802721                   数据分析   37500
# 1       5204912                   数据建模   15000
# 2       6877668                   数据分析    3500
# 3       6496141                   数据分析   45000
# 4       6467417                   数据分析   30000
# ..          ...                    ...     ...
# 100     6884346                  数据分析师   25000
# 101     6849100                 商业数据分析   35000
# 102     6803432        奔驰·耀出行-BI数据分析专家   30000
# 103     6704835                BI数据分析师   20000
# 104     6728058  数据分析专家-LQ(J181203029)   21500
#
# [105 rows x 3 columns]

# %% [markdown]
# ###  8 读取 Excel 文件｜指定列（匹配）
#
# <br>
#
# **根据指定列名匹配读取**
#
# 让我们来个更难一点的，还是读取 `某招聘网站数据.csv` 文件，但现在有一个 list 中包含多个字段👇
#
# `usecols = ['positionId','test','positionName', 'test1','salary']`
#
# 如果 `usecols` 中的列名存在于 `某招聘网站数据.csv` 中，则读取。

# %%
usecols = ['positionId','test','positionName', 'test1','salary']

# %%
data=pd.read_csv("某招聘网站数据.csv",usecols=lambda c:c in set(usecols))
data

# %%
usecols=['positionID','test','positionName','test1','salary']
data=pd.read_csv("某招聘网站数据.csv",usecols=lambda c:c in (usecols))
data

# %% [markdown]
# ### 9 读取 Excel 文件｜指定索引
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并在读取时将 `positionId` 设置为索引列

# %%
data=pd.read_csv("某招聘网站数据.csv",index_col=['positionId'])

# %%
data

# %% [markdown]
# ###  10 读取 Excel 文件｜指定标题
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件的 `positionId、positionName、salary` 列，并将标题设置为 `ID、岗位名称、薪资`

# %%
data=pd.read_csv("某招聘网站数据.csv",
        usecols=[0,1,17],
        header=0,
        names=['ID','岗位名称','薪资']
        )

# %%
data

# %% [markdown]
# ###  11 读取 Excel 文件｜缺失值转换
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并不将缺失值标记为 `NA`**
#
# 思考：为什么要这样做？

# %%
data=pd.read_csv("某招聘网站数据.csv",keep_default_na=True)

# %%
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %%
data=pd.read_csv("某招聘网站数据.csv",keep_default_na=False)

# %%
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...           0       0       0
# 1          建模  ...           0       0       0
# 2        数据分析  ...           0       0       0
# 3        数据分析  ...           0       0       0
# 4        数据分析  ...           0       0       0
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...           0       0       0
# 101    商业数据分析  ...           0       0       0
# 102      数据分析  ...           0       0       0
# 103      数据分析  ...           0       0       0
# 104    其他数据分析  ...           0       0       0
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                                 0      0                   []         False
# 1                                 0      0                   []         False
# 2                                 0      0                   []         False
# 3                                 0      0                   []          True
# 4                                 0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                               0      0                   []         False
# 101                               0      0                   []         False
# 102                               0      0                   []         False
# 103                               0      0                   []          True
# 104                               0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ###  12 读取 Excel 文件｜缺失值标记
#
# <br>
#
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**并将`[]`标记为缺失值**

# %%
data=pd.read_csv("某招聘网站数据.csv",na_values=['[]'])

# %%
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                NaN  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                  NaN         False
# 1                     NaN         0      0                  NaN         False
# 2                     NaN         0      0                  NaN         False
# 3                     NaN         0      0                  NaN          True
# 4                     NaN         0      0                  NaN          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                  NaN         False
# 101                   NaN         0      0                  NaN         False
# 102                   NaN         0      0                  NaN         False
# 103                   NaN         0      0                  NaN          True
# 104                   NaN         0      0                  NaN          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 13 读取 Excel 文件｜忽略缺失值
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，**但不处理缺失值**
#
# 思考：和之前的有什么不同，为什么这么做？

# %%
data=pd.read_csv("某招聘网站数据.csv",na_filter=True)

# %%
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...  NaN      0       0       0              NaN
# 1          建模  ...  NaN      0       0       0              NaN
# 2        数据分析  ...  NaN      0       0       0              NaN
# 3        数据分析  ...  NaN      0       0       0              NaN
# 4        数据分析  ...  NaN      0       0       0              NaN
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...  NaN      0       0       0              NaN
# 101    商业数据分析  ...  NaN      0       0       0              NaN
# 102      数据分析  ...  NaN      0       0       0              NaN
# 103      数据分析  ...  NaN      0       0       0              NaN
# 104    其他数据分析  ...  NaN      0       0       0              NaN
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                     NaN         0      0                   []         False
# 1                     NaN         0      0                   []         False
# 2                     NaN         0      0                   []         False
# 3                     NaN         0      0                   []          True
# 4                     NaN         0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                   NaN         0      0                   []         False
# 101                   NaN         0      0                   []         False
# 102                   NaN         0      0                   []         False
# 103                   NaN         0      0                   []          True
# 104                   NaN         0      0                   []          True
#
# [105 rows x 52 columns]

# %%
data=pd.read_csv("某招聘网站数据.csv",na_filter=False)

# %%
data
# Out:
#      positionId           positionName  companyId companySize industryField  \
# 0       6802721                   数据分析     475770     50-150人      移动互联网,电商
# 1       5204912                   数据建模      50735    150-500人            电商
# 2       6877668                   数据分析     100125     2000人以上    移动互联网,企业服务
# 3       6496141                   数据分析      26564   500-2000人            电商
# 4       6467417                   数据分析      29211     2000人以上         物流丨运输
# ..          ...                    ...        ...         ...           ...
# 100     6884346                  数据分析师      21236   500-2000人   移动互联网,医疗丨健康
# 101     6849100                 商业数据分析      72076   500-2000人      移动互联网,电商
# 102     6803432        奔驰·耀出行-BI数据分析专家     751158    150-500人         移动互联网
# 103     6704835                BI数据分析师      52840     2000人以上            电商
# 104     6728058  数据分析专家-LQ(J181203029)       2474     2000人以上         汽车丨出行
#
#     financeStage                   companyLabelList  firstType secondType  \
# 0             A轮   ['绩效奖金', '带薪年假', '定期体检', '弹性工作']  产品|需求|项目类       数据分析
# 1             B轮   ['年终奖金', '做五休二', '六险一金', '子女福利']  开发|测试|运维类       数据开发
# 2           上市公司   ['节日礼物', '年底双薪', '股票期权', '带薪年假']  产品|需求|项目类       数据分析
# 3          D轮及以上  ['生日趴', '每月腐败基金', '每月补贴', '年度旅游']  开发|测试|运维类       数据开发
# 4           上市公司   ['技能培训', '免费班车', '专项奖金', '岗位晋升']  产品|需求|项目类       数据分析
# ..           ...                                ...        ...        ...
# 100           C轮   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  产品|需求|项目类       数据分析
# 101           C轮   ['节日礼物', '股票期权', '带薪年假', '年度旅游']     市场|商务类      市场|营销
# 102        不需要融资                                 []  开发|测试|运维类       数据开发
# 103         上市公司   ['技能培训', '年底双薪', '节日礼物', '绩效奖金']  开发|测试|运维类       数据开发
# 104        不需要融资   ['弹性工作', '节日礼物', '岗位晋升', '技能培训']  产品|需求|项目类       数据分析
#
#     thirdType  ... plus pcShow appShow deliver gradeDescription  \
# 0        数据分析  ...           0       0       0
# 1          建模  ...           0       0       0
# 2        数据分析  ...           0       0       0
# 3        数据分析  ...           0       0       0
# 4        数据分析  ...           0       0       0
# ..        ...  ...  ...    ...     ...     ...              ...
# 100      数据分析  ...           0       0       0
# 101    商业数据分析  ...           0       0       0
# 102      数据分析  ...           0       0       0
# 103      数据分析  ...           0       0       0
# 104    其他数据分析  ...           0       0       0
#
#     promotionScoreExplain isHotHire  count aggregatePositionIds famousCompany
# 0                                 0      0                   []         False
# 1                                 0      0                   []         False
# 2                                 0      0                   []         False
# 3                                 0      0                   []          True
# 4                                 0      0                   []          True
# ..                    ...       ...    ...                  ...           ...
# 100                               0      0                   []         False
# 101                               0      0                   []         False
# 102                               0      0                   []         False
# 103                               0      0                   []          True
# 104                               0      0                   []          True
#
# [105 rows x 52 columns]

# %% [markdown]
# ### 14 读取 Excel 文件｜指定格式
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `positionId,companyId` 设置为字符串格式

# %%
data=pd.read_csv("某招聘网站数据.csv")

# %%
data.info()#info是获取信息的意思
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   positionId             105 non-null    int64
#  1   positionName           105 non-null    object
#  2   companyId              105 non-null    int64
#  3   companySize            105 non-null    object
#  4   industryField          105 non-null    object
#  5   financeStage           105 non-null    object
#  6   companyLabelList       105 non-null    object
#  7   firstType              105 non-null    object
#  8   secondType             105 non-null    object
#  9   thirdType              105 non-null    object
#  10  skillLables            105 non-null    object
#  11  positionLables         105 non-null    object
#  12  industryLables         105 non-null    object
#  13  createTime             105 non-null    object
#  14  formatCreateTime       105 non-null    object
#  15  district               105 non-null    object
#  16  businessZones          53 non-null     object
#  17  salary                 105 non-null    int64
#  18  workYear               105 non-null    object
#  19  jobNature              105 non-null    object
#  20  education              105 non-null    object
#  21  positionAdvantage      105 non-null    object
#  22  imState                105 non-null    object
#  23  lastLogin              105 non-null    object
#  24  publisherId            105 non-null    int64
#  25  approve                105 non-null    int64
#  26  subwayline             45 non-null     object
#  27  stationname            45 non-null     object
#  28  linestaion             45 non-null     object
#  29  latitude               105 non-null    float64
#  30  longitude              105 non-null    float64
#  31  hitags                 2 non-null      object
#  32  resumeProcessRate      105 non-null    int64
#  33  resumeProcessDay       105 non-null    int64
#  34  score                  105 non-null    int64
#  35  newScore               105 non-null    int64
#  36  matchScore             105 non-null    float64
#  37  matchScoreExplain      0 non-null      float64
#  38  query                  0 non-null      float64
#  39  explain                0 non-null      float64
#  40  isSchoolJob            105 non-null    int64
#  41  adWord                 105 non-null    int64
#  42  plus                   0 non-null      float64
#  43  pcShow                 105 non-null    int64
#  44  appShow                105 non-null    int64
#  45  deliver                105 non-null    int64
#  46  gradeDescription       0 non-null      float64
#  47  promotionScoreExplain  0 non-null      float64
#  48  isHotHire              105 non-null    int64
#  49  count                  105 non-null    int64
#  50  aggregatePositionIds   105 non-null    object
#  51  famousCompany          105 non-null    bool
# dtypes: bool(1), float64(9), int64(16), object(26)
# memory usage: 42.1+ KB

# %%
data=pd.read_csv("某招聘网站数据.csv",
        dtype={'positionId':str,'companyId':str})

# %%
data.info()

# %% [markdown]
# ### 15 读取 Excel 文件｜指定格式（时间）
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，并将 `createTime` 列设置为字符串格式

# %%
data=pd.read_csv("某招聘网站数据.csv",parse_dates=["createTime"])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105 entries, 0 to 104
# Data columns (total 52 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   positionId             105 non-null    int64
#  1   positionName           105 non-null    object
#  2   companyId              105 non-null    int64
#  3   companySize            105 non-null    object
#  4   industryField          105 non-null    object
#  5   financeStage           105 non-null    object
#  6   companyLabelList       105 non-null    object
#  7   firstType              105 non-null    object
#  8   secondType             105 non-null    object
#  9   thirdType              105 non-null    object
#  10  skillLables            105 non-null    object
#  11  positionLables         105 non-null    object
#  12  industryLables         105 non-null    object
#  13  createTime             105 non-null    datetime64[ns]
#  14  formatCreateTime       105 non-null    object
#  15  district               105 non-null    object
#  16  businessZones          53 non-null     object
#  17  salary                 105 non-null    int64
#  18  workYear               105 non-null    object
#  19  jobNature              105 non-null    object
#  20  education              105 non-null    object
#  21  positionAdvantage      105 non-null    object
#  22  imState                105 non-null    object
#  23  lastLogin              105 non-null    object
#  24  publisherId            105 non-null    int64
#  25  approve                105 non-null    int64
#  26  subwayline             45 non-null     object
#  27  stationname            45 non-null     object
#  28  linestaion             45 non-null     object
#  29  latitude               105 non-null    float64
#  30  longitude              105 non-null    float64
#  31  hitags                 2 non-null      object
#  32  resumeProcessRate      105 non-null    int64
#  33  resumeProcessDay       105 non-null    int64
#  34  score                  105 non-null    int64
#  35  newScore               105 non-null    int64
#  36  matchScore             105 non-null    float64
#  37  matchScoreExplain      0 non-null      float64
#  38  query                  0 non-null      float64
#  39  explain                0 non-null      float64
#  40  isSchoolJob            105 non-null    int64
#  41  adWord                 105 non-null    int64
#  42  plus                   0 non-null      float64
#  43  pcShow                 105 non-null    int64
#  44  appShow                105 non-null    int64
#  45  deliver                105 non-null    int64
#  46  gradeDescription       0 non-null      float64
#  47  promotionScoreExplain  0 non-null      float64
#  48  isHotHire              105 non-null    int64
#  49  count                  105 non-null    int64
#  50  aggregatePositionIds   105 non-null    object
#  51  famousCompany          105 non-null    bool
# dtypes: bool(1), datetime64[ns](1), float64(9), int64(16), object(25)
# memory usage: 42.1+ KB

# %% [markdown]
# ### 16 读取 Excel 文件｜分块读取
#
#
# <br>
#
# 读取当前目录下 `某招聘网站数据.csv` 文件，要求返回一个可迭代对象，每次读取 10 行
#
# 思考：为什么这样做？

# %%
import pandas as pd

# %%
total_datas=[]
eachData=pd.read_csv("某招聘网站.csv")
for i in range(1000000):
  total_datas.append(eachData)
total_datas=pd.concat(total_datas)
total_datas.to_csv('total.csv')

# %%
data=pd.read_csv("某招聘网站数据.csv",chunksize=10)#可迭代的文件读取器

# %%
data

# %%
for chunk in data:
  #print(chunk.shape)
  #pd.concat()#连接
# Out:
#   File "<ipython-input-10-3de23c02107d>", line 3
#     #pd.concat()
#                 ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# ### 17 读取 txt 文件｜常规
#
# <br>
#
# 读取当前目录下 `Titanic.txt` 文件。
#
# 注意：在接下来的几种格式文件读取中，对于之前重复的参数/功能将不再整理，仅介绍读取功能。windows中要改文件属性才能看到文件拓展名
# CSV:以逗号分隔的数据文本文件
# Excel：传统的表格保存

# %%
data=pd.read_table("Titanic.txt")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 36.0+ KB

# %% [markdown]
# ### 18 读取 txt 文件｜含中文
#
# <br>
#
# 读取当前目录下 `TOP250.txt` 文件。

# %%
data=pd.read_table("TOP250.txt",encoding='gb18030')
data.info()
#data=pd.read_csv("TOP250.txt",encoding='gb18030,sep='\t')#使用read_csv
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   片名      250 non-null    object
#  1   上映年份    250 non-null    int64
#  2   评分      250 non-null    float64
#  3   评价人数    250 non-null    int64
#  4   导演      250 non-null    object
#  5   编剧      250 non-null    object
#  6   主演      250 non-null    object
#  7   类型      250 non-null    object
#  8   国家/地区   250 non-null    object
#  9   语言      250 non-null    object
#  10  时长(分钟)  250 non-null    int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 21.6+ KB

# %% [markdown]
# ### 19 读取 JSON 文件
#
#
#
# <br>
#
# 读取当前目录下 `某基金数据.json` 文件。

# %%
data=pd.read_table("TOP250.txt",encoding='gb18030')
data
# Out:
#            片名  上映年份   评分     评价人数        导演  \
# 0      肖申克的救赎  1994  9.7  2317937  弗兰克·德拉邦特
# 1        霸王别姬  1993  9.6  1720638       陈凯歌
# 2        阿甘正传  1994  9.5  1743966  罗伯特·泽米吉斯
# 3     这个杀手不太冷  1994  9.4  1922740     吕克·贝松
# 4       泰坦尼克号  1997  9.4  1706127   詹姆斯·卡梅隆
# ..        ...   ...  ...      ...       ...
# 245        浪潮  2008  8.7   223511   丹尼斯·甘塞尔
# 246  小萝莉的猴神大叔  2015  8.4   404886     卡比尔·汗
# 247        追随  1998  8.9   149521  克里斯托弗·诺兰
# 248      网络谜踪  2018  8.6   430811   阿尼什·查甘蒂
# 249      黑鹰坠落  2001  8.7   239402   雷德利·斯科特
#
#                                                编剧  \
# 0                                弗兰克·德拉邦特 / 斯蒂芬·金
# 1                                        芦苇 / 李碧华
# 2                                艾瑞克·罗斯 / 温斯顿·格鲁姆
# 3                                           吕克·贝松
# 4                                         詹姆斯·卡梅隆
# ..                                            ...
# 245  丹尼斯·甘塞尔 / 彼得·图万斯 / 约翰尼·道金斯 / 罗恩·比恩巴赫 / 罗恩·琼斯
# 246                            卡比尔·汗 / 维杰耶德拉·普拉萨德
# 247                                      克里斯托弗·诺兰
# 248                             阿尼什·查甘蒂 / 赛弗·奥哈尼安
# 249                                  肯·诺兰 / 马克·鲍登
#
#                                                     主演                 类型  \
# 0    蒂姆·罗宾斯 / 摩根·弗里曼 / 鲍勃·冈顿 / 威廉姆·赛德勒 / 克兰西·布朗 / 吉...            剧情 / 犯罪
# 1    张国荣 / 张丰毅 / 巩俐 / 葛优 / 英达 / 蒋雯丽 / 吴大维 / 吕齐 / 雷汉...       剧情 / 爱情 / 同性
# 2    汤姆·汉克斯 / 罗宾·怀特 / 加里·西尼斯 / 麦凯尔泰·威廉逊 / 莎莉·菲尔德 / ...            剧情 / 爱情
# 3    让·雷诺 / 娜塔莉·波特曼 / 加里·奥德曼 / 丹尼·爱罗 / 彼得·阿佩尔 / 迈克尔...       剧情 / 动作 / 犯罪
# 4    莱昂纳多·迪卡普里奥 / 凯特·温丝莱特 / 比利·赞恩 / 凯西·贝茨 / 弗兰西丝·费舍...       剧情 / 爱情 / 灾难
# ..                                                 ...                ...
# 245  于尔根·福格尔 / 弗雷德里克·劳 / 马克思·雷迈特 / 詹妮弗·乌尔里希 / 克里斯蒂安...            剧情 / 惊悚
# 246  萨尔曼·汗 / 哈莎莉·马洛特拉 / 卡琳娜·卡普尔 / 纳瓦祖丁·席迪圭 / 欧姆·普瑞 ...       剧情 / 喜剧 / 动作
# 247  杰里米·西奥伯德 / 亚历克斯·霍 / 露西·拉塞尔 / 约翰·诺兰 / 迪克·布拉德塞尔 ...       悬疑 / 惊悚 / 犯罪
# 248  约翰·赵 / 米切尔·拉 / 黛博拉·梅辛 / 约瑟夫·李 / 萨拉·米博·孙 / 亚历克丝...  剧情 / 悬疑 / 惊悚 / 犯罪
# 249  乔什·哈奈特 / 伊万·麦克格雷格 / 汤姆·塞兹摩尔 / 金·寇兹 / 艾文·布莱纳 / ...       动作 / 历史 / 战争
#
#     国家/地区     语言  时长(分钟)
# 0      美国     英语     142
# 1      中国  汉语普通话     171
# 2      美国     英语     142
# 3      法国    英语      110
# 4      美国    英语      194
# ..    ...    ...     ...
# 245    德国     德语     107
# 246    印度   印地语      159
# 247    英国     英语      69
# 248    美国     英语     102
# 249    美国    英语      144
#
# [250 rows x 11 columns]

# %% [markdown]
# ### 20 读取 HDF5 文件
#
# <br>
#
# `HDF5`是一种特殊的文件格式，常见于在大规模存储数据上
#
# 关于 `pandas` 与 `hdf5` 格式文件的操作较多，下面仅学习如何读取。
#
# 读取当前目录下`store_tl.h5`文件

# %%
data=pd.read_hdf("store_tl.h5","table")
data
# Out:
#        A    B
# 0      0    0
# 1      1    1
# 2      2    2
# 3      3    3
# 4      4    4
# ..   ...  ...
# 495  495  495
# 496  496  496
# 497  497  497
# 498  498  498
# 499  499  499
#
# [505 rows x 2 columns]

# %% [markdown]
# ### 21 从剪贴板读取数据
#
# <br>
#
# 打开当前目录下 `Titanic.txt` 文件，全选并复制。
#
# 现在直接从剪贴板读取数据。

# %%
data=pd.read_clipboard()
data
# Out:
# ---------------------------------------------------------------------------
# PyperclipException                        Traceback (most recent call last)
# <ipython-input-30-e5db723d2a44> in <module>
# ----> 1 data=pd.read_clipboard()
#       2 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboards.py in read_clipboard(sep, **kwargs)
#      39     from pandas.io.parsers import read_csv
#      40
# ---> 41     text = clipboard_get()
#      42
#      43     # Try to decode (if needed, as "text" might already be a string here).
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboard/__init__.py in lazy_load_stub_paste()
#     653     global copy, paste
#     654     copy, paste = determine_clipboard()
# --> 655     return paste()
#     656
#     657
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/clipboard/__init__.py in __call__(self, *args, **kwargs)
#     292     class ClipboardUnavailable:
#     293         def __call__(self, *args, **kwargs):
# --> 294             raise PyperclipException(EXCEPT_MSG)
#     295
#     296         def __bool__(self) -> bool:
#
# PyperclipException:
#     Pyperclip could not find a copy/paste mechanism for your system.
#     For more information, please visit
#     https://pyperclip.readthedocs.io/en/latest/#not-implemented-error

# %% [markdown]
# ### 22 从 SQL 读取数据
#
# <br>
#
# 有时我们需要从 `SQL` 中读取数据，如果先将数据导出再`pandas`读取并不是一个合适的选择。
#
# 在 `pandas` 中支持直接从 `sql` 中查询并读取。
#
# 为了方便统一操作，请先执行下面的代码创建数据。

# %%
pd.read_sql('SELECT int_column,date_column FROM test_data',conn)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f8d44d43e9ac> in <module>
# ----> 1 pd.read_sql('SELECT int_column,date_column FROM test_data',conn)
#
# NameError: name 'conn' is not defined

# %% [markdown]
# 下面将 `SQL` 语句 `SELECT int_column, date_column FROM test_data` 转换为 `DataFrame`

# %%
# Out:
#    int_column date_column
# 0           0    10/11/12
# 1           1    12/11/10

# %% [markdown]
# ### 23 从网页读取数据
#
# <br>
#
# 直接从东京奥运会官网读取奖牌榜数据。
#
# 目标网站地址为 `https://olympics.com/tokyo-2020/olympic-games/zh/results/all-sports/medal-standings.htm`
#
# 思考：什么类型的在线表格可以直接读取？

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_html("https://olympice.com/tokyo-2020/olympic-games/zh/results/all-sports/medal-sta")
data

# %%
APPL="https://www.nasdaq.com/market-activity/stocks/aapl/historical#.UWdnJBFMhHk"
data=pd.read_html(APPL)[0]
data
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-af919ad154ec> in <module>
#       1 APPL="https://www.nasdaq.com/market-activity/stocks/aapl/historical#.UWdnJBFMhHk"
# ----> 2 data=pd.read_html(APPL)[0]
#       3 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1111         na_values=na_values,
#    1112         keep_default_na=keep_default_na,
# -> 1113         displayed_only=displayed_only,
#    1114     )
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     904
#     905         try:
# --> 906             tables = p.parse_tables()
#     907         except ValueError as caught:
#     908             # if `io` is an io-like object, check if it's seekable
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in parse_tables(self)
#     220         list of parsed (header, body, footer) tuples from tables.
#     221         """
# --> 222         tables = self._parse_tables(self._build_doc(), self.match, self.attrs)
#     223         return (self._parse_thead_tbody_tfoot(table) for table in tables)
#     224
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/html.py in _build_doc(self)
#     724         try:
#     725             if is_url(self.io):
# --> 726                 with urlopen(self.io) as f:
#     727                     r = parse(f, parser=parser)
#     728             else:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     210     import urllib.request
#     211
# --> 212     return urllib.request.urlopen(*args, **kwargs)
#     213
#     214
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# /usr/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in https_open(self, req)
#    1391         def https_open(self, req):
#    1392             return self.do_open(http.client.HTTPSConnection, req,
# -> 1393                 context=self._context, check_hostname=self._check_hostname)
#    1394
#    1395         https_request = AbstractHTTPHandler.do_request_
#
# /usr/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1351             except OSError as err: # timeout error
#    1352                 raise URLError(err)
# -> 1353             r = h.getresponse()
#    1354         except:
#    1355             h.close()
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 24 循环读取数据
#
# <br>
#
# 在本小节 `demodata` 文件夹下有多个 `Excel` 文件，要求一次性循环读取全部文件

# %%
import os
path='/demodata'
filenames=os.listdir(path)
filenames=[f for f in filenames if f.lower().endwidth(".xlsx")]
df_list[10]
for filename in filenames:
  df_list.append(pd.read_excel(path+filename))
df=pd.concat(df_list)
data
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-a832adb9cddf> in <module>
#       1 import os
#       2 path='/demodata'
# ----> 3 filenames=os.listdir(path)
#       4 filenames=[f for f in filenames if f.lower().endwidth(".xlsx")]
#       5 df_list[10]
#
# FileNotFoundError: [Errno 2] No such file or directory: '/demodata'

# %% [markdown]
# ## 1-2 数据创建
#
# <br>
#
# 除了直接读取本地文件，学会直接创建数据框也很重要，常见于测试一些函数，下面是从常见数据结构创建数据框的方法整理

# %% [markdown]
# ### 25 从列表创建
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定列名为`"林肯Python"`

# %%
l = [1,2,3,4,5]

# %%
import pandas as pd

# %%
data=pd.DataFrame(1,columns=['林肯Python'])
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-1189f1343666> in <module>
# ----> 1 data=pd.DataFrame(1,columns=['林肯Python'])
#       2 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
data=pd.DataFrame(1)
data

# %% [markdown]
# ### 26 从列表创建｜嵌套列表
#
# <br>
#
# 将下面的 `list` 转换为 `dataframe`，并指定行索引为`"公众号","林肯Python"`

# %%
l = [[1,2,3],[4,5,6]]

# %%
data=pd.DataFrame(1,index=['公号','林肯Python'])
data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-3ca6b71426e1> in <module>
# ----> 1 data=pd.DataFrame(1,index=['公号','林肯Python'])
#       2 data
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     728         else:
#     729             if index is None or columns is None:
# --> 730                 raise ValueError("DataFrame constructor not properly called!")
#     731
#     732             # Argument 1 to "ensure_index" has incompatible type "Collection[Any]";
#
# ValueError: DataFrame constructor not properly called!

# %%
data=pd.DataFrame(1)
data

# %% [markdown]
# ### 27 从字典创建

# %% [markdown]
# 执行下方代码，并将字典转换为`dataframe`

# %%
d = {
    "one": pd.Series([1.0, 2.0, 3.0], index=["a", "b", "c"]),
    "two": pd.Series([1.0, 2.0, 3.0, 4.0], index=["a", "b", "c", "d"]) }

# %%
data=pd.DataFrame(1,index=['公号','林肯Python'],columns=['A','B','C'])
data
# Out:
#           A  B  C
# 公号        1  1  1
# 林肯Python  1  1  1

# %%
data=pd.DataFrame(d)
data
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# c  3.0  3.0
# d  NaN  4.0

# %% [markdown]
# ### 28 从字典创建｜指定索引
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`

# %%
data=pd.DataFrame(d,index=["a","b","d"])
data
# Out:
#    one  two
# a  1.0  1.0
# b  2.0  2.0
# d  NaN  4.0

# %% [markdown]
# ### 29 从字典创建｜指定列名
#
# <br>
#
# 还是上一题的字典`d`，将其转换为`dataframe`并指定索引顺序为 `d、b、a`，列名为`"two", "three"`

# %%
data = pd.DataFrame(d, index=["d", "b", "a"], columns=["two", "three"])
data
# Out:
#    two three
# d  4.0   NaN
# b  2.0   NaN
# a  1.0   NaN

# %% [markdown]
# ### 30 从字典创建｜字典列表
# <br>
#
# 将下方列表型字典转换为`dataframe`
#
# 思考：如何指定行/列索引？

# %%
d = [{"a": 1, "b": 2}, {"a": 5, "b": 10, "c": 20}]

# %%
data=pd.DataFrame(d)
data
# Out:
#    a   b     c
# 0  1   2   NaN
# 1  5  10  20.0

# %% [markdown]
# ### 31 从集合创建
#
# <br>
#
# 将下面的元组转换为 dataframe 且行列索引均为 `1,2,3,4`

# %%
t =((1,0,0,0,)
  ,(2,3,0,0,),
  (4,5,6,0,),
  (7,8,9,10,)
  )

# %%
data=pd.DataFrame(t,columns=[1,2,3,4],index=[1,2,3,4])
data
# Out:
#    1  2  3   4
# 1  1  0  0   0
# 2  2  3  0   0
# 3  4  5  6   0
# 4  7  8  9  10

# %% [markdown]
# ## 1-3 数据存储

# %% [markdown]
# ### 32 保存为 CSV
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意）

# %%
data = pd.read_csv("某招聘网站数据.csv",nrows = 20)

# %%
data=pd.to_csv("out.csv",encoding='utf_8_sig')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-73-1223a365c5e1> in <module>
# ----> 1 data=pd.to_csv("out.csv",encoding='utf_8_sig')
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %% [markdown]
# ### 33 保存为 CSV｜指定列
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且只保留`positionName、salary`两列

# %%
data=pd.to_csv("out.csv",encoding='utf_8_sig',column=['positionName','salary'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-af4b0fedcd71> in <module>
# ----> 1 data=pd.to_csv("out.csv",encoding='utf_8_sig',column=['positionName','salary'])
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'to_csv'

# %% [markdown]
# ### 34 保存为 CSV｜取消索引
#
# <br>
#
# 将第三题读取到的数据保存为 `csv` 格式至当前目录下（文件名任意），且取消每一行的索引

# %%
data=pd.to_csv("out.csv",encoding='utf_8_sig',index=False)

# %% [markdown]
# ### 35 保存为 CSV｜标记缺失值
#
# <br>
#
# 在上一题的基础上，在保存的同时，将缺失值标记为`'数据缺失'`

# %%
data=pd.to_csv("out.csv",encoding='utf_8_sig',index=False,na_rep='数据缺失')

# %% [markdown]
# ### 36 保存为CSV｜压缩
#
# <br>
#
# 将上一题的数据保存至 `zip` 文件，解压后出现 `out.csv`

# %%
from pandas.io.formats.format import CompressionOptions
CompressionOptions
# Out:
# typing.Union[str, typing.Dict[str, typing.Any], NoneType]

# %%
compression_opts=dict(method='zip',
          archive_name='out.csv')
data.to_csv('out.zip',index=False,
      compression=compression_opts)

# %% [markdown]
# ### 37 保存为 Excel
#
# <br>
#
# 将第三题读取到的数据保存为 `xlsx` 格式至当前目录下（文件名任意）

# %%
data.to_excel("test.xlsx")

# %% [markdown]
# ### 38 保存为 JSON
#
# 将之前的数据保存为 `json` 格式至当前目录下（文件名任意）

# %%
data.to_json("out.json")

# %% [markdown]
# ### 39 保存为 Markdown

# %% [markdown]
# 将之前数据转换为 `markdown` 形式表格，这样可以直接复制进 `.md` 文件中使用

# %%
data.head().to_markdown(index=None)
# Out:
# "|   positionId | positionName   |   companyId | companySize   | industryField       | financeStage   | companyLabelList                                   | firstType        | secondType   | thirdType   | skillLables                         | positionLables                                      | industryLables                                      | createTime      | formatCreateTime   | district   | businessZones          |   salary | workYear   | jobNature   | education   | positionAdvantage                      | imState   | lastLogin       |   publisherId |   approve | subwayline   | stationname   | linestaion                               |   latitude |   longitude | hitags   |   resumeProcessRate |   resumeProcessDay |   score |   newScore |   matchScore | matchScoreExplain   | query   | explain   |   isSchoolJob |   adWord | plus   |   pcShow |   appShow |   deliver | gradeDescription   | promotionScoreExplain   |   isHotHire |   count | aggregatePositionIds   | famousCompany   |\n|-------------:|:---------------|------------:|:--------------|:--------------------|:---------------|:---------------------------------------------------|:-----------------|:-------------|:------------|:------------------------------------|:----------------------------------------------------|:----------------------------------------------------|:----------------|:-------------------|:-----------|:-----------------------|---------:|:-----------|:------------|:------------|:---------------------------------------|:----------|:----------------|--------------:|----------:|:-------------|:--------------|:-----------------------------------------|-----------:|------------:|:---------|--------------------:|-------------------:|--------:|-----------:|-------------:|:--------------------|:--------|:----------|--------------:|---------:|:-------|---------:|----------:|----------:|:-------------------|:------------------------|------------:|--------:|:-----------------------|:----------------|\n|      6802721 | 数据分析       |      475770 | 50-150人      | 移动互联网,电商     | A轮            | ['绩效奖金', '带薪年假', '定期体检', '弹性工作']   | 产品|需求|项目类 | 数据分析     | 数据分析    | ['SQL', '数据库', '数据运营', 'BI'] | ['电商', '社交', 'SQL', '数据库', '数据运营', 'BI'] | ['电商', '社交', 'SQL', '数据库', '数据运营', 'BI'] | 2020/3/16 11:00 | 11:00发布          | 余杭区     | ['仓前']               |    37500 | 1-3年      | 全职        | 本科        | 五险一金、弹性工作、带薪年假、年度体检 | today     | 2020/3/16 11:00 |      12022406 |         1 |              |               |                                          |    30.2784 |     120.006 |          |                  50 |                  1 |     233 |          0 |      15.1019 |                     |         |           |             0 |        0 |        |        0 |         0 |         0 |                    |                         |           0 |       0 | []                     | False           |\n|      5204912 | 数据建模       |       50735 | 150-500人     | 电商                | B轮            | ['年终奖金', '做五休二', '六险一金', '子女福利']   | 开发|测试|运维类 | 数据开发     | 建模        | ['算法', '数据架构']                | ['算法', '数据架构']                                | []                                                  | 2020/3/16 11:08 | 11:08发布          | 滨江区     | ['西兴', '长河']       |    15000 | 3-5年      | 全职        | 本科        | 六险一金,定期体检,丰厚年终             | disabled  | 2020/3/16 11:08 |       5491688 |         1 |              |               |                                          |    30.188  |     120.201 |          |                  23 |                  1 |     176 |          0 |      32.5594 |                     |         |           |             0 |        0 |        |        0 |         0 |         0 |                    |                         |           0 |       0 | []                     | False           |\n|      6877668 | 数据分析       |      100125 | 2000人以上    | 移动互联网,企业服务 | 上市公司       | ['节日礼物', '年底双薪', '股票期权', '带薪年假']   | 产品|需求|项目类 | 数据分析     | 数据分析    | ['数据库', '数据分析', 'SQL' ...

# %% [markdown]
# ### 40 保存为 Html
#
# 将之前的数据保存为 `html` 格式至当前目录下（文件名任意），并进行如下设置
# - 取消行索引
# - 标题居中对齐
# - 列宽100

# %%
data=pd.read_csv("某招聘网站数据.csv")

# %%
data.to_html("out.html",col_space=100,index=None,justify='center',border=1)
